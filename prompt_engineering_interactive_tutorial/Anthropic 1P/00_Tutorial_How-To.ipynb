# %% [markdown]
# # Návod Jak Na To
#
# Tento návod **vyžaduje API klíč** pro interakci. Pokud nemáte API klíč, můžete se zaregistrovat pro jeden prostřednictvím [Anthropic Console](https://console.anthropic.com/) nebo si místo toho prohlédnout náš [statický klíč odpovědí k návodu](https://docs.google.com/spreadsheets/u/0/d/1jIxjzUWG-6xBVIa2ay6yDpLyeuOh_hR_ZB75a47KX_E/edit).

# %% [markdown]
# ## Jak začít
#
# 1. Naklonujte toto úložiště na svůj lokální počítač.
#
# 2. Nainstalujte potřebné závislosti spuštěním následujícího příkazu:

# %%
# %pip install anthropic

# %% [markdown]
# 3. Nastavte svůj API klíč a název modelu. Nahraďte `"your_api_key_here"` vaším skutečným Anthropic API klíčem.

# %%
```python
API_KEY = "your_api_key_here"
MODEL_NAME = "claude-3-haiku-20240307"

# Ukládá proměnné API_KEY a MODEL_NAME pro použití napříč notebooky v rámci IPython store
# %store API_KEY
# %store MODEL_NAME
```

# %% [markdown]
# 4. Spusťte buňky v notebooku v pořadí, podle poskytnutých instrukcí.

# %% [markdown]
# ---
#
# ## Poznámky k použití a tipy 💡
#
# - Tento kurz používá Claude 3 Haiku s teplotou 0. O teplotě budeme mluvit později v kurzu. Prozatím stačí pochopit, že tato nastavení poskytují více deterministické výsledky. Všechny techniky prompt engineeringu v tomto kurzu se také vztahují na starší generace modelů Claude, jako jsou Claude 2 a Claude Instant 1.2.
#
# - Můžete použít `Shift + Enter` k provedení buňky a přechodu na další.
#
# - Když dosáhnete konce stránky s tutoriálem, přejděte na další očíslovaný soubor ve složce, nebo na další očíslovanou složku, pokud jste dokončili obsah v rámci daného kapitoly.
#
# ### Anthropic SDK a Messages API
# V tomto tutoriálu budeme používat [Anthropic python SDK](https://docs.anthropic.com/claude/reference/client-sdks) a [Messages API](https://docs.anthropic.com/claude/reference/messages_post).
#
# Níže je příklad, jak bude vypadat spuštění promptu v tomto tutoriálu. Nejprve vytvoříme `get_completion`, což je pomocná funkce, která odešle prompt do Claude a vrátí generovanou odpověď od Claude. Spusťte tuto buňku nyní.

# %%
import anthropic

client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# Nyní napíšeme příklad promptu pro Claude a vytiskneme výstup Claude spuštěním naší pomocné funkce `get_completion`. Spuštění buňky níže vytiskne odpověď od Claude pod ní.
#
# Neváhejte si pohrát s řetězcem promptu, abyste získali různé odpovědi od Claude.

# %%
```python
# Prompt
prompt = "Hello, Claude!"

# Získání odpovědi od Claude
print(get_completion(prompt))
```

# %% [markdown]
# Proměnné `API_KEY` a `MODEL_NAME` definované dříve budou použity v celém tutoriálu. Jen se ujistěte, že spouštíte buňky pro každou stránku tutoriálu odshora dolů.
