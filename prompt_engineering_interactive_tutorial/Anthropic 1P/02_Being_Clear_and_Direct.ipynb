# %% [markdown]
# # Kapitola 2: Být jasný a přímý
#
# - [Lekce](#lesson)
# - [Cvičení](#exercises)
# - [Příkladové hřiště](#example-playground)
#
# ## Nastavení
#
# Spusťte následující buňku nastavení pro načtení vašeho API klíče a vytvoření pomocné funkce `get_completion`.

# %%
# %pip install anthropic

# Import vestavěnou knihovnu regulárních výrazů v Pythonu
import re
import anthropic

# Načtení proměnných API_KEY a MODEL_NAME z úložiště IPython
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

# Všimněte si, že jsme změnili max_tokens na 4K pouze pro tuto lekci, abychom umožnili delší dokončení v cvičeních
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# ---
#
# ## Lekce
#
# **Claude reaguje nejlépe na jasné a přímé instrukce.**
#
# Představte si Claude jako každého jiného člověka, který je nový v práci. **Claude nemá žádný kontext** o tom, co dělat, kromě toho, co mu doslova řeknete. Stejně jako když poprvé instruujete člověka o úkolu, čím více přesně vysvětlíte, co chcete, přímočaře Claudeovi, tím lepší a přesnější bude Claudeova odpověď.
#
# Když máte pochybnosti, řiďte se **Zlatým pravidlem jasného promptu**:
# - Ukažte svůj prompt kolegovi nebo příteli a nechte je, aby sami následovali instrukce, aby zjistili, zda mohou dosáhnout výsledku, který chcete. Pokud jsou zmatení, Claude je zmatený.

# %% [markdown]
# ### Příklady
#
# Podívejme se na úkol, jako je psaní poezie. (Ignorujte jakýkoli nesoulad v počtu slabik - LLM ještě nejsou skvělé v počítání slabik.)

# %%
```python
# Prompt
PROMPT = "Write a haiku about robots."

# Vytisknout odpověď od Claude
print(get_completion(PROMPT))
```

# %% [markdown]
# Tento haiku je dost pěkný, ale uživatelé mohou chtít, aby Claude přešel přímo k básni bez úvodu "Tady je haiku".
#
# Jak toho dosáhneme? **Požádáme o to**!

# %%
```python
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Vytisknout odpověď od Claude
print(get_completion(PROMPT))
```

# %% [markdown]
# Zde je další příklad. Zkusme se zeptat Claude, kdo je nejlepší basketbalista všech dob. Jak můžete vidět níže, Claude sice uvede několik jmen, **ale neodpovídá s jednoznačným "nejlepším"**.

# %%
```python
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Vytiskni odpověď od Claude
print(get_completion(PROMPT))
```

# %% [markdown]
# Můžeme přimět Claude, aby se rozhodl a určil nejlepšího hráče? Ano! Stačí se zeptat!

# %%
```python
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Vytisknout Claudeovu odpověď
print(get_completion(PROMPT))
```

# %% [markdown]
# Pokud byste chtěli experimentovat s prompty lekce, aniž byste měnili jakýkoli obsah výše, přejděte až na konec poznámkového bloku lekce a navštivte [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Cvičení
# - [Cvičení 2.1 - Španělština](#exercise-21---spanish)
# - [Cvičení 2.2 - Pouze jeden hráč](#exercise-22---one-player-only)
# - [Cvičení 2.3 - Napište příběh](#exercise-23---write-a-story)

# %% [markdown]
# ### Cvičení 2.1 - Španělština
# Upravte `SYSTEM_PROMPT`, aby Claude poskytoval svou odpověď ve španělštině.

# %%
```python
# Systémový prompt - toto je jediné pole, které byste měli změnit
SYSTEM_PROMPT = "[Replace this text]"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Získat odpověď od Claude
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Funkce pro hodnocení správnosti cvičení
def grade_exercise(text):
    return "hola" in text.lower()

# Vytisknout odpověď od Claude a odpovídající hodnocení
print(response)
print("\n--------------------------- HODNOCENÍ ---------------------------")
print("Toto cvičení bylo správně vyřešeno:", grade_exercise(response))
```

# %% [markdown]
# ❓ Pokud chcete nápovědu, spusťte buňku níže!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)

# %% [markdown]
# ### Cvičení 2.2 - Pouze jeden hráč
#
# Upravte `PROMPT` tak, aby Claude vůbec neváhal a odpověděl **POUZE** jménem jednoho konkrétního hráče, **bez dalších slov nebo interpunkce**.

# %%
```python
# Prompt - toto je jediné pole, které byste měli změnit
PROMPT = "[Replace this text]"

# Získat odpověď od Claude
response = get_completion(PROMPT)

# Funkce pro hodnocení správnosti cvičení
def grade_exercise(text):
    return text == "Michael Jordan"

# Vytisknout odpověď od Claude a odpovídající hodnocení
print(response)
print("\n--------------------------- HODNOCENÍ ---------------------------")
print("Toto cvičení bylo správně vyřešeno:", grade_exercise(response))
```

# %% [markdown]
# ❓ Pokud chcete nápovědu, spusťte buňku níže!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)

# %% [markdown]
# ### Cvičení 2.3 - Napište příběh
#
# Upravte `PROMPT` tak, aby Claude odpověděl co nejdelší odpovědí, jakou dokážete vytvořit. Pokud vaše odpověď má **přes 800 slov**, bude Claudeova odpověď hodnocena jako správná.

# %%
```python
# Prompt - toto je jediné pole, které byste měli změnit
PROMPT = "[Replace this text]"

# Získat odpověď od Claude
response = get_completion(PROMPT)

# Funkce pro hodnocení správnosti cvičení
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Vytisknout odpověď od Claude a odpovídající hodnocení
print(response)
print("\n--------------------------- HODNOCENÍ ---------------------------")
print("Toto cvičení bylo správně vyřešeno:", grade_exercise(response))
```

# %% [markdown]
# ❓ Pokud chcete nápovědu, spusťte buňku níže!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)

# %% [markdown]
# ### Gratulujeme!
#
# Pokud jste vyřešili všechny úkoly až do tohoto bodu, jste připraveni přejít k další kapitole. Přejeme šťastné promptování!

# %% [markdown]
# ---
#
# ## Příklad hřiště
#
# Toto je prostor, kde můžete volně experimentovat s příklady promptů uvedenými v této lekci a upravovat prompty, abyste viděli, jak to může ovlivnit odpovědi Claude.

# %%
```python
# Prompt
PROMPT = "Write a haiku about robots."

# Vytisknout odpověď od Claude
print(get_completion(PROMPT))
```

# %%
```python
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Vytisknout odpověď od Claude
print(get_completion(PROMPT))
```

# %%
```python
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Vytiskni Claudeovu odpověď
print(get_completion(PROMPT))
```

# %%
```python
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Vytisknout Claudeovu odpověď
print(get_completion(PROMPT))
```
